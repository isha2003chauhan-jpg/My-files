# %% [markdown]
# # String exercise

# %% [markdown]
# 1. Create a string "Python Programming" and print only "Programming" using slicing.

# %%
string = "Python Programming" 
print(string[7:])
# Out:
# Programming

# %% [markdown]
# 2. From "Hello World", print "World" using negative indexing.

# %%
string = "Hello World"
print(string[-5:])
# Out:
# World

# %% [markdown]
# 3. Given text = "Developer", print every second character using slicing.

# %%
text = "Developer"
print(text[: :2])
# Out:
# Dvlpr

# %% [markdown]
# 4. Reverse the string "OpenAI" using slicing.

# %%
string =  "OpenAI"
print(string[: : -1])
# Out:
# IAnepO

# %% [markdown]
# 5. Extract "gram" from "Programming" using slicing.

# %%
string = "Programming"
print(string[3:7])
# Out:
# gram

# %% [markdown]
# 6. Given text = "Data Science", replace "Science" with "Analysis".

# %%
text = "Data Science"
print(text.replace("Science","Analysis"))
# Out:
# Data Analysis

# %% [markdown]
# 7. Convert "python is fun" into uppercase and store it in a new variable.

# %%
str = "python is fun"
str1 = str.upper()
print(str1 )
# Out:
# PYTHON IS FUN

# %% [markdown]
# 8. Convert "WELCOME" into lowercase and print it.

# %%
str =  "WELCOME"
print(str.lower())
# Out:
# welcome

# %% [markdown]
# 9. Count how many times "e" appears in "experience"

# %%
str =  "experience"
print(str.count("e"))
# Out:
# 4

# %% [markdown]
# 10. Find the index of "a" in "banana" (first occurrence).

# %%
str = "banana"
print(str.find("a"))
# Out:
# 1

# %% [markdown]
# 11. Remove leading and trailing spaces from " Hello Python ".

# %%
str = "Hello Python"
print(str.strip())
# Out:
# Hello Python

# %% [markdown]
# 12. Replace all spaces in "I love coding" with _.

# %%
str =  "I love coding" 
print(str.replace(" ","_"))
# Out:
# I_love_coding

# %% [markdown]
# 13. From "ABCDEFGHIJ", extract "CDEFG" using slicing.

# %%
str = "ABCDEFGHIJ"
str[2:7]
# Out:
# 'CDEFG'

# %% [markdown]
# 14. Print the last 4 characters of "JavaScript".

# %%
str =  "JavaScript"
print(str[-4:])
# Out:
# ript

# %% [markdown]
# 15. From "FullStack", print characters from index 1 to second last.

# %%
str = "FullStack"
print(str[1:-1])
# Out:
# ullStac

# %% [markdown]
# 16. Create variables: name = "Aman", age = 25. Use f-string to print "My name is Aman and I am 25
# years old".

# %%
name = "Aman"
age = 25
print(f"My name is {name} and i am {age} years old")
# Out:
# My name is Aman and i am 25 years old

# %% [markdown]
# 17. Create variables: apples = 3, bananas = 2. Use .format() to print "I have 3 apples and 2
# bananas".

# %%
apples = 3
bananas = 2
print("i have {} apples and {} bananas".format(apples,bananas))
# Out:
# i have 3 apples and 2 bananas

# %% [markdown]
# 18. Print the string: This is "Python" using escape characters.

# %%
print('This is "Python"')
# Out:
# This is "Python"

# %% [markdown]
# 19. Create a multi-line string for an address using triple quotes.

# %%
str = """Hi, i am isha and i am from delhi. currently i am living in Mayur vihar"""
print(str)
# Out:
# Hi, i am isha and i am from delhi. currently i am living in Mayur vihar

# %% [markdown]
# 20. Print a string with a new line using \n

# %%
str = "isha\nkhushi\nDucat"
print(str)
# Out:
# isha
# khushi
# Ducat

# %% [markdown]
# 21. Convert "hello world" into "Hello World" using string methods.

# %%
str = "hello world"
print(str.title())
# Out:
# Hello World

# %% [markdown]
# 22. Swap the case of "PyThOn".

# %%
str =  "PyThOn"
print(str.swapcase())
# Out:
# pYtHoN

# %% [markdown]
# 23. Find the length of "Artificial Intelligence".

# %%
str =  "Artificial Intelligence"
print(len(str))
# Out:
# 23

# %% [markdown]
# 24. From "MachineLearning", extract "Learning" using slicing.

# %%
str =  "MachineLearning"
print(str[7:])
# Out:
# Learning

# %% [markdown]
# 25. Print characters from index 2 to 8 in "DataAnalytics".

# %%
str = "DataAnalytics"
print(str[2:9])
# Out:
# taAnaly

# %% [markdown]
# 26. Replace "2024" with "2025" in "Happy New Year 2024".

# %%
str = "Happy New Year 2024"
print(str.replace("2024","2025"))
# Out:
# Happy New Year 2025

# %% [markdown]
# 27. Find the position of "@" in "user@gmail.com".

# %%
str =  "user@gmail.com"
print(str.find("@"))
# Out:
# 4

# %% [markdown]
# 28. Convert "123" (string) into integer.

# %%
str = "123"
print(int(str))
# Out:
# 123

# %% [markdown]
# 29. Convert integer 456 into string and concatenate with "Number: ".

# %%
num=456
num=str(456)
string=num+"number"
print(string)
# Out:
# 456number

# %% [markdown]
# 30. Remove all occurrences of "a" from "banana" using string methods

# %%
str = "banana"
print(str.replace("a",""))
# Out:
# bnn
